# %%
# Import libraries
import numpy as np
import pandas as pd
import seaborn as sns

# %%
t_by_participants = pd.read_csv('data/02_cleaned/by_participants/t_by_participants.csv')
e_by_participants = pd.read_csv('data/02_cleaned/by_participants/e_by_participants.csv')

# %%
t_by_participants
# Out:
#           participant    tense  mean_up  sum_up  mean_right  sum_right  \
# 0   R_1115aM2ViF0qAvd   future   0.6875      11      0.8125         13
# 1   R_1115aM2ViF0qAvd     past   0.5625       9      0.6875         11
# 2   R_1115aM2ViF0qAvd  present   0.5625       9      0.9375         15
# 3   R_1E0AxSxnOgbjq0q   future   0.2500       4      0.7500         12
# 4   R_1E0AxSxnOgbjq0q     past   0.5000       8      0.1250          2
# ..                ...      ...      ...     ...         ...        ...
# 94  R_u2F46KzhjElPZPH     past   0.6875      11      0.5625          9
# 95  R_u2F46KzhjElPZPH  present   0.6250      10      0.6250         10
# 96  R_wX0KseqnhRAM6yZ   future   0.5625       9      0.1875          3
# 97  R_wX0KseqnhRAM6yZ     past   0.5000       8      0.5000          8
# 98  R_wX0KseqnhRAM6yZ  present   0.5000       8      0.5000          8
#
#     depression_sum  anxiety_sum  stress_sum  n_item
# 0             13.0          8.0        17.0      16
# 1             13.0          8.0        17.0      16
# 2             13.0          8.0        17.0      16
# 3             13.0         10.0        11.0      16
# 4             13.0         10.0        11.0      16
# ..             ...          ...         ...     ...
# 94             8.0          8.0         7.0      16
# 95             8.0          8.0         7.0      16
# 96             9.0         10.0        13.0      16
# 97             9.0         10.0        13.0      16
# 98             9.0         10.0        13.0      16
#
# [99 rows x 10 columns]

# %%
sns.boxplot(
    x="tense", 
    y="mean_right", 
    data=t_by_participants
)
# Out:
# <AxesSubplot:xlabel='tense', ylabel='mean_right'>
